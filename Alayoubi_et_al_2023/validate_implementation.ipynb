# %% [markdown]
# # Compare p-values between propeller and scanpro implementations

# %%
import os
import sys
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Scanpro functions
from scanpro import scanpro

#Setup path to R for propeller
R_home = os.path.dirname(sys.executable)[:-4] + "/lib/R"
os.environ["R_HOME"] = R_home
# %load_ext rpy2.ipython

# %%
def convert_counts_to_df(counts, prop_cols=None, meta_cols=None, n_cells=1, column_name="Cluster"):
    """ Convert a cell count matrix to a dataframe in long format."""

    counts = counts.copy()

    #If not given, try to get prop_cols and meta_cols automatically
    if prop_cols is None:
        dtypes = counts.dtypes.astype(str)
        prop_cols = [col for i, col in enumerate(counts.columns) if "float" in dtypes[i] or "int" in dtypes[i]]
        
    if meta_cols is None:
        meta_cols = [col for col in counts.columns if col not in prop_cols]

    # Multiply proportions with n_cells
    counts[prop_cols] *= n_cells
    counts[prop_cols] = counts[prop_cols].astype(int)
    
    # Melt into long format (similar to adata.obs)
    counts_melt = pd.melt(counts, id_vars=meta_cols, value_vars=prop_cols, 
                          var_name=column_name, value_name="count")

    # Duplicate rows based on number of cells
    counts_long = counts_melt.loc[counts_melt.index.repeat(counts_melt["count"])].reset_index(drop=True)
    counts_long.drop(columns="count", inplace=True)
    counts_long.index = ["cell_" + str(i) for i in range(1, len(counts_long) + 1)]
    
    return counts_long

# %% [markdown]
# --------

# %% [markdown]
# ## PBMC - 2 conditions

# %%
pbmc_counts = pd.read_csv("data/pbmc_counts.tsv", sep="\t")
pbmc = convert_counts_to_df(pbmc_counts, column_name="Celltype")

# %%
scanpro_out = scanpro.scanpro(pbmc, samples_col='Sample', clusters_col='Celltype', conds_col='Sex')
# Out:
# [INFO] There are 2 conditions. T-Test will be performed...
# [INFO] Done!

# %%
# %%R -i pbmc -o propeller_results
# library(speckle)
#
# propeller_results = propeller(clusters = pbmc$Celltype, sample = pbmc$Sample, group = pbmc$Sex)
# Out:
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
# The legacy packages maptools, rgdal, and rgeos, underpinning the sp package,
# which was just loaded, will retire in October 2023.
# Please refer to R-spatial evolution reports for details, especially
# https://r-spatial.org/r/2023/05/15/evolution4.html.
# It may be desirable to make the sf package available;
# package maintainers should consider adding sf to Suggests:.
# The sp package is now running under evolution status 2
#      (status 2 uses the sf package in place of rgdal)
# Performing logit transformation of proportions
# group variable has 2 levels, t-tests will be performed

# %%
scanpro_out.results
# Out:
#           baseline_props  mean_props_female  mean_props_male  prop_ratio  \
# Celltype
# BC              0.098383           0.101042         0.095581    1.057138
# DC              0.017112           0.015587         0.018793    0.829422
# MC              0.171416           0.168821         0.171046    0.986995
# NK              0.146479           0.116914         0.174684    0.669285
# TC              0.566610           0.597636         0.539896    1.106946
#
#           t_statistics  p_values  adjusted_p_values
# Celltype
# BC            0.453598  0.651210           0.814013
# DC           -1.054917  0.294287           0.490479
# MC           -0.063599  0.949430           0.949430
# NK           -2.636203  0.009874           0.049371
# TC            1.447690  0.151178           0.377946

# %%
propeller_results = propeller_results.sort_index()
propeller_results
# Out:
#    BaselineProp.clusters  BaselineProp.Freq  PropMean.female  PropMean.male  \
# BC                    BC           0.098383         0.101042       0.095581
# DC                    DC           0.017112         0.015587       0.018793
# MC                    MC           0.171416         0.168821       0.171046
# NK                    NK           0.146479         0.116914       0.174684
# TC                    TC           0.566610         0.597636       0.539896
#
#     PropRatio  Tstatistic   P.Value       FDR
# BC   1.057138    0.453546  0.651248  0.814059
# DC   0.829422   -1.052536  0.295371  0.492285
# MC   0.986995   -0.063694  0.949355  0.949355
# NK   0.669285   -2.637317  0.009844  0.049221
# TC   1.106946    1.448420  0.150975  0.377437

# %%
scanpro_out.results.iloc[:,-1] - propeller_results.iloc[:,-1]
# Out:
# Celltype
# BC   -0.000047
# DC   -0.001807
# MC    0.000075
# NK    0.000150
# TC    0.000509
# dtype: float64

# %% [markdown]
# --------

# %% [markdown]
# ## PBMC with covariates

# %%
scanpro_out = scanpro.scanpro(pbmc, samples_col='Sample', clusters_col='Celltype', conds_col='Sex', covariates="Age")
# Out:
# [INFO] There are 2 conditions. T-Test will be performed...
# [INFO] Done!

# %%
scanpro_out.results
# Out:
#           baseline_props  mean_props_female  mean_props_male  prop_ratio  \
# Celltype
# BC              0.098383           0.101042         0.095581    1.057138
# DC              0.017112           0.015587         0.018793    0.829422
# MC              0.171416           0.168821         0.171046    0.986995
# NK              0.146479           0.116914         0.174684    0.669285
# TC              0.566610           0.597636         0.539896    1.106946
#
#           t_statistics  p_values  adjusted_p_values
# Celltype
# BC            0.466193  0.642270           0.802838
# DC           -1.094385  0.276878           0.461463
# MC           -0.066020  0.947517           0.947517
# NK           -2.699387  0.008380           0.041900
# TC            1.496382  0.138258           0.345645

# %%
sample_info = pbmc[["Sample", "Condition", "Sex", "Age"]].drop_duplicates()

# %%
# %%R -i pbmc -i sample_info -o propeller_result
# library(limma)
#
# sex <- sample_info$Sex
# age <- sample_info$Age
#
# design <- model.matrix(~ 0 + sex + age)
# props <- getTransformedProps(pbmc$Celltype, pbmc$Sample, transform="logit")
#
# mycontr <- makeContrasts("sexmale-sexfemale", levels=design)
#
# propeller_result = propeller.ttest(props, design, contrasts=mycontr, robust=TRUE, trend=FALSE, sort=TRUE)
# Out:
# Performing logit transformation of proportions

# %%
propeller_result = propeller_result.sort_index()
propeller_result
# Out:
#     PropMean.sexfemale  PropMean.sexmale  PropRatio  Tstatistic   P.Value  \
# BC            0.101042          0.095581   0.945950   -0.465948  0.642444
# DC            0.015587          0.018793   1.205659    1.093562  0.277237
# MC            0.168821          0.171046   1.013177    0.066221  0.947357
# NK            0.116914          0.174684   1.494132    2.697454  0.008425
# TC            0.597636          0.539896   0.903387   -1.498186  0.137790
#
#          FDR
# BC  0.803055
# DC  0.462061
# MC  0.947357
# NK  0.042124
# TC  0.344474

# %%
scanpro_out.results.iloc[:,-1] - propeller_result.iloc[:,-1]
# Out:
# Celltype
# BC   -0.000218
# DC   -0.000598
# MC    0.000160
# NK   -0.000224
# TC    0.001171
# dtype: float64

# %% [markdown]
# ----------------

# %% [markdown]
# ## Heart - 3 conditions

# %%
heart_counts = pd.read_csv("data/heart_counts.tsv", sep="\t")
heart = convert_counts_to_df(heart_counts, column_name="Celltype")

# %%
scanpro_out = scanpro.scanpro(heart, samples_col='Sample',
                             clusters_col='Celltype', conds_col='Condition')
# Out:
# [INFO] There are more than 2 conditions. ANOVA will be performed...
# [INFO] Done!

# %%
# %%R -i heart -o propeller_results
# library(speckle)
#
# propeller_results = propeller(clusters = heart$Celltype, sample = heart$Sample,
#                               group = heart$Condition)
# Out:
# Performing logit transformation of proportions
# group variable has > 2 levels, ANOVA will be performed

# %%
scanpro_out.results
# Out:
#                      baseline_props  mean_props_adult  mean_props_fetal  \
# Celltype
# Cardiomyocytes             0.549464          0.273547          0.682410
# Endothelial cells          0.101607          0.124538          0.102108
# Epicardial cells           0.064167          0.093158          0.051415
# Erythroid                  0.002272          0.000000          0.004433
# Fibroblast                 0.182102          0.298689          0.111342
# Immune cells               0.076302          0.189588          0.027546
# Neurons                    0.016143          0.011381          0.012643
# Smooth muscle cells        0.007942          0.009099          0.008102
#
#                      mean_props_young  f_statistics  p_values  \
# Celltype
# Cardiomyocytes               0.426761      8.998537  0.000124
# Endothelial cells            0.092478      0.337551  0.713515
# Epicardial cells             0.075410      0.901016  0.406157
# Erythroid                    0.000000    197.947461  0.000000
# Fibroblast                   0.261924      4.602496  0.010027
# Immune cells                 0.108751     11.508649  0.000010
# Neurons                      0.026210      1.545816  0.213138
# Smooth muscle cells          0.008465      0.403828  0.667759
#
#                      adjusted_p_values
# Celltype
# Cardiomyocytes                0.000330
# Endothelial cells             0.713515
# Epicardial cells              0.541542
# Erythroid                     0.000000
# Fibroblast                    0.020054
# Immune cells                  0.000040
# Neurons                       0.341021
# Smooth muscle cells           0.713515

# %%
propeller_results = propeller_results.sort_index()
propeller_results
# Out:
#                      BaselineProp  PropMean.adult  PropMean.fetal  \
# Cardiomyocytes           0.549464        0.273547        0.682410
# Endothelial cells        0.101607        0.124538        0.102108
# Epicardial cells         0.064167        0.093158        0.051415
# Erythroid                0.002272       -0.000000        0.004433
# Fibroblast               0.182102        0.298689        0.111342
# Immune cells             0.076302        0.189588        0.027546
# Neurons                  0.016143        0.011381        0.012643
# Smooth muscle cells      0.007942        0.009099        0.008102
#
#                      PropMean.young  Fstatistic       P.Value           FDR
# Cardiomyocytes             0.426761    9.068229  1.152704e-04  3.073879e-04
# Endothelial cells          0.092478    0.340093  7.117040e-01  7.117040e-01
# Epicardial cells           0.075410    0.909787  4.026099e-01  5.368133e-01
# Erythroid                 -0.000000   46.591998  5.825757e-21  4.660605e-20
# Fibroblast                 0.261924    4.630794  9.747019e-03  1.949404e-02
# Immune cells               0.108751   11.575093  9.397256e-06  3.758902e-05
# Neurons                    0.026210    1.519245  2.188770e-01  3.502033e-01
# Smooth muscle cells        0.008465    0.421692  6.559362e-01  7.117040e-01

# %%
scanpro_out.results.iloc[:,-1] - propeller_results.iloc[:,-1]
# Out:
# Celltype
# Cardiomyocytes         2.218666e-05
# Endothelial cells      1.811479e-03
# Epicardial cells       4.728979e-03
# Erythroid             -4.660605e-20
# Fibroblast             5.595227e-04
# Immune cells           2.582390e-06
# Neurons               -9.182506e-03
# Smooth muscle cells    1.811479e-03
# dtype: float64

# %% [markdown]
# -----------

# %% [markdown]
# ## Human MI - 2 conditions

# %%
human_MI_counts = pd.read_csv("data/human_MI_counts.tsv", sep="\t")
human_MI = convert_counts_to_df(human_MI_counts, column_name="cell_type")

# %%
scanpro_out = scanpro.scanpro(human_MI, samples_col='sample',
                            clusters_col='cell_type', conds_col='major_label', 
                            conditions=['CTRL','IZ'])

scanpro_out.results
# Out:
# [INFO] There are 2 conditions. T-Test will be performed...
# [INFO] Done!
#                baseline_props  mean_props_CTRL  mean_props_IZ  prop_ratio  \
# cell_type
# Adipocyte            0.000407         0.000355       0.002084    0.170583
# Cardiomyocyte        0.120837         0.442471       0.152491    2.901614
# Cycling cells        0.013488         0.005429       0.063373    0.085660
# Endothelial          0.065925         0.146923       0.207000    0.709772
# Fibroblast           0.103209         0.225862       0.271549    0.831755
# Lymphoid             0.009500         0.012775       0.043002    0.297090
# Mast                 0.001449         0.003495       0.003041    1.149458
# Myeloid              0.050434         0.074778       0.185137    0.403904
# Neuronal             0.004009         0.013734       0.007297    1.882211
# Pericyte             0.022853         0.064351       0.048875    1.316650
# vSMCs                0.004880         0.009826       0.016152    0.608347
#
#                t_statistics  p_values  adjusted_p_values
# cell_type
# Adipocyte          0.019170  0.984957           0.984957
# Cardiomyocyte      2.754764  0.014670           0.080683
# Cycling cells     -5.800573  0.000034           0.000374
# Endothelial       -1.280809  0.219574           0.301915
# Fibroblast        -0.658671  0.520020           0.572022
# Lymphoid          -2.238372  0.040671           0.095190
# Mast               1.301492  0.212588           0.301915
# Myeloid           -2.476843  0.025553           0.093696
# Neuronal           2.206098  0.043268           0.095190
# Pericyte           1.394666  0.183286           0.301915
# vSMCs             -1.014722  0.326215           0.398707

# %%
human_MI_sub = human_MI[human_MI["major_label"].isin(["CTRL", "IZ"])]

# %%
scanpro_out = scanpro.scanpro(human_MI_sub, samples_col='sample',
                            clusters_col='cell_type', conds_col='major_label')

scanpro_out.results
# Out:
# [INFO] There are 2 conditions. T-Test will be performed...
# [INFO] Done!
#                baseline_props  mean_props_CTRL  mean_props_IZ  prop_ratio  \
# cell_type
# Adipocyte            0.001024         0.000355       0.002084    0.170583
# Cardiomyocyte        0.304383         0.442471       0.152491    2.901614
# Cycling cells        0.033976         0.005429       0.063373    0.085660
# Endothelial          0.166060         0.146923       0.207000    0.709772
# Fibroblast           0.259978         0.225862       0.271549    0.831755
# Lymphoid             0.023929         0.012775       0.043002    0.297090
# Mast                 0.003651         0.003495       0.003041    1.149458
# Myeloid              0.127041         0.074778       0.185137    0.403904
# Neuronal             0.010100         0.013734       0.007297    1.882211
# Pericyte             0.057564         0.064351       0.048875    1.316650
# vSMCs                0.012293         0.009826       0.016152    0.608347
#
#                t_statistics  p_values  adjusted_p_values
# cell_type
# Adipocyte          0.019170  0.984957           0.984957
# Cardiomyocyte      2.754764  0.014670           0.080683
# Cycling cells     -5.800573  0.000034           0.000374
# Endothelial       -1.280809  0.219574           0.301915
# Fibroblast        -0.658671  0.520020           0.572022
# Lymphoid          -2.238372  0.040671           0.095190
# Mast               1.301492  0.212588           0.301915
# Myeloid           -2.476843  0.025553           0.093696
# Neuronal           2.206098  0.043268           0.095190
# Pericyte           1.394666  0.183286           0.301915
# vSMCs             -1.014722  0.326215           0.398707

# %%
# %%R -i human_MI_sub -o propeller_results
# library(speckle)
#
# propeller_results = propeller(clusters = human_MI_sub$cell_type, sample = human_MI_sub$sample,
#                                group = human_MI_sub$major_label)
# Out:
# Performing logit transformation of proportions
# group variable has 2 levels, t-tests will be performed

# %%
propeller_results = propeller_results.sort_index().iloc[:,1:]
propeller_results
# Out:
#                BaselineProp.Freq  PropMean.CTRL  PropMean.IZ  PropRatio  \
# Adipocyte               0.001024       0.000355     0.002084   0.170583
# Cardiomyocyte           0.304383       0.442471     0.152491   2.901614
# Cycling cells           0.033976       0.005429     0.063373   0.085660
# Endothelial             0.166060       0.146923     0.207000   0.709772
# Fibroblast              0.259978       0.225862     0.271549   0.831755
# Lymphoid                0.023929       0.012775     0.043002   0.297090
# Mast                    0.003651       0.003495     0.003041   1.149458
# Myeloid                 0.127041       0.074778     0.185137   0.403904
# Neuronal                0.010100       0.013734     0.007297   1.882211
# Pericyte                0.057564       0.064351     0.048875   1.316650
# vSMCs                   0.012293       0.009826     0.016152   0.608347
#
#                Tstatistic   P.Value       FDR
# Adipocyte       -1.442505  0.167690  0.307432
# Cardiomyocyte    2.862045  0.010955  0.060253
# Cycling cells   -5.845425  0.000017  0.000185
# Endothelial     -1.198902  0.246433  0.338846
# Fibroblast      -0.633622  0.534463  0.534463
# Lymphoid        -2.281753  0.035166  0.092934
# Mast             1.052531  0.307578  0.347670
# Myeloid         -2.459512  0.024498  0.089827
# Neuronal         2.189828  0.042243  0.092934
# Pericyte         1.274589  0.218999  0.338846
# vSMCs           -1.031910  0.316064  0.347670

# %%
scanpro_out.results.iloc[:,-1] - propeller_results.iloc[:,-1]
# Out:
# cell_type
# Adipocyte        0.677524
# Cardiomyocyte    0.020430
# Cycling cells    0.000189
# Endothelial     -0.036931
# Fibroblast       0.037560
# Lymphoid         0.002256
# Mast            -0.045755
# Myeloid          0.003869
# Neuronal         0.002256
# Pericyte        -0.036931
# vSMCs            0.051037
# dtype: float64

# %% [markdown]
# --------------

# %% [markdown]
# ## Human MI - 3 conditions

# %%
scanpro_out = scanpro.scanpro(human_MI, samples_col='sample',
                             clusters_col='cell_type', conds_col='major_label', conditions=["CTRL", "IZ", "FZ"])

scanpro_out.results
# Out:
# [INFO] There are more than 2 conditions. ANOVA will be performed...
# [INFO] Done!
#                baseline_props  mean_props_CTRL  mean_props_FZ  mean_props_IZ  \
# cell_type
# Adipocyte            0.001611         0.000355       0.007654       0.002084
# Cardiomyocyte        0.160458         0.442471       0.160938       0.152491
# Cycling cells        0.014166         0.005429       0.004619       0.063373
# Endothelial          0.106718         0.146923       0.244929       0.207000
# Fibroblast           0.154775         0.225862       0.286012       0.271549
# Lymphoid             0.017091         0.012775       0.050783       0.043002
# Mast                 0.002763         0.003495       0.007942       0.003041
# Myeloid              0.077494         0.074778       0.148286       0.185137
# Neuronal             0.006132         0.013734       0.012309       0.007297
# Pericyte             0.033166         0.064351       0.047683       0.048875
# vSMCs                0.009807         0.009826       0.028846       0.016152
#
#                f_statistics      p_values  adjusted_p_values
# cell_type
# Adipocyte          1.623507  1.972058e-01       3.098949e-01
# Cardiomyocyte      3.932092  1.960262e-02       5.390722e-02
# Cycling cells     35.222196  5.551115e-16       6.106227e-15
# Endothelial        1.037603  3.543030e-01       4.330370e-01
# Fibroblast         0.463950  6.287953e-01       6.287953e-01
# Lymphoid           1.886445  1.516098e-01       2.779513e-01
# Mast               0.791893  4.529866e-01       4.982852e-01
# Myeloid            2.265912  1.037354e-01       2.282178e-01
# Neuronal           4.372135  1.262425e-02       4.628893e-02
# Pericyte           1.090112  3.361788e-01       4.330370e-01
# vSMCs              4.586013  1.019341e-02       4.628893e-02

# %%
human_MI_sub = human_MI[human_MI["major_label"].isin(["CTRL", "IZ", "FZ"])]

# %%
# %%R -i human_MI_sub -o propeller_results
# library(speckle)
#
# propeller_results = propeller(clusters = human_MI_sub$cell_type, sample = human_MI_sub$sample,
#                               group = human_MI_sub$major_label)
# Out:
# Performing logit transformation of proportions
# group variable has > 2 levels, ANOVA will be performed

# %%
propeller_results = propeller_results.sort_index()
propeller_results
# Out:
#                BaselineProp  PropMean.CTRL  PropMean.FZ  PropMean.IZ  \
# Adipocyte          0.002758       0.000355     0.007654     0.002084
# Cardiomyocyte      0.274671       0.442471     0.160938     0.152491
# Cycling cells      0.024250       0.005429     0.004619     0.063373
# Endothelial        0.182680       0.146923     0.244929     0.207000
# Fibroblast         0.264943       0.225862     0.286012     0.271549
# Lymphoid           0.029257       0.012775     0.050783     0.043002
# Mast               0.004730       0.003495     0.007942     0.003041
# Myeloid            0.132654       0.074778     0.148286     0.185137
# Neuronal           0.010496       0.013734     0.012309     0.007297
# Pericyte           0.056773       0.064351     0.047683     0.048875
# vSMCs              0.016788       0.009826     0.028846     0.016152
#
#                Fstatistic       P.Value       FDR
# Adipocyte        2.590385  9.853004e-02  0.216766
# Cardiomyocyte    4.084748  3.159201e-02  0.086878
# Cycling cells   34.910101  1.456055e-07  0.000002
# Endothelial      0.990286  3.873776e-01  0.481172
# Fibroblast       0.430831  6.553169e-01  0.655317
# Lymphoid         1.967866  1.635130e-01  0.256949
# Mast             0.535401  5.931482e-01  0.652463
# Myeloid          2.297940  1.239966e-01  0.227327
# Neuronal         4.139840  2.973166e-02  0.086878
# Pericyte         0.972694  3.936866e-01  0.481172
# vSMCs            4.339787  2.573237e-02  0.086878

# %%
scanpro_out.results.iloc[:,-1] - propeller_results.iloc[:,-1]
# Out:
# cell_type
# Adipocyte        0.093129
# Cardiomyocyte   -0.032971
# Cycling cells   -0.000002
# Endothelial     -0.048135
# Fibroblast      -0.026522
# Lymphoid         0.021002
# Mast            -0.154178
# Myeloid          0.000891
# Neuronal        -0.040589
# Pericyte        -0.048135
# vSMCs           -0.040589
# dtype: float64
